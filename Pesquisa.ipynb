# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data_process = pd.read_csv("entrada.csv")
alarm_var = pd.read_csv("alarm_list.csv")

# %%
data_process
# Out:
#    tout   x0    x1   x2
# 0  10.2  3.2  10.2  8.3
# 1  10.2  3.2  10.2  8.3

# %%
alarm_var
# Out:
#    limit  type  delay_time  dead_band      name proc_ver
# 0   10.0  high         1.3        1.9    tanque       x0
# 1    9.0   low         1.0        1.4  tanque_2       x1

# %%
def step_signal (low, s_low, high, s_high, larg_high_i, larg_high_f, larg_low_i, larg_low_f, prob_positivo, n):
       
    distrib = np.random.binomial(1,prob_positivo,n)
    signal = np.concatenate([np.random.uniform(high-s_high,high+s_high,np.random.randint(larg_high_i, larg_high_f)) if x == 1 else np.random.uniform(low-s_low,low+s_low,np.random.randint(larg_low_i, larg_low_f)) for x in distrib])
    return signal

# %%
signal = step_signal(3, 0.5, 9, 0.2, 20, 100, 30, 100, 0.5, 50)
plt.figure(figsize=(16,4))
plt.plot(signal)
plt.show()

# %%
signal = np.linspace(0,4*np.pi, 1000)

signal_ruido = [np.random.uniform(-0.1,0.1) for x in signal]

# signal_ruido
# plt.plot(signal_ruido)
plt.figure(figsize=(16,4))
plt.plot(signal,np.sin(signal)+signal_ruido)
plt.show()

# %%
t = np.linspace(0,10)
x = 1 - np.exp(-t)

plt.plot(t,x)

# %%
t = np.linspace(0,100, 100)

#x = 1 - np.exp(-t/10) + t*np.exp(-t/0.1)

x = (1/10*np.sqrt(2*np.pi))*np.exp(-np.power((t-50),2)/(np.power(2*10,2)))

plt.plot(t,x)
